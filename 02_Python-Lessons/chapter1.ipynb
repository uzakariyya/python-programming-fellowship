# %% [markdown]
# # Chapter 1: Getting Started
#
# ## Objectives
#
# By the end of this chapter, you will be able to:
# - Verify if Python is installed on your system and check its version.
# - Install Python and set up your development environment.
# - Understand the different ways to run Python code, including using the command line and Python interpreters.
# - Write and execute simple Python programs.
# - Recognize the importance of using Python 3 over Python 2.

# %% [markdown]
# ## Python Editor (VSCode Editor)
#
# - Vscode , Atom , JupterLab , PyCharm , Spyder
#
# - VScode
#    - Clone Repo (Arewa python programming)
#    - Markdown
#    - PDF
#    - Pull remote changes
#    - Create new Assigment Repo
#      - clone it
#      - add folders
#    - Create a workshpace and Save

# %% [markdown]
# ## Python Version?
#
# - CommandLine python -V or python --version
#
# - Why care about the version?
#
# - version 2 versus version 3
#
#   - Python 2 is no longer supported

# %%
# how to check python version in notebook (this is called comment)
# !python --version
# Out:
# Python 3.9.13

# %%
# Check Python Version Using Python Code
import sys # import system module

# Print the Python version using sys module
print(sys.version)
# Out:
# 3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)
# [Clang 13.0.1 ]

# %% [markdown]
# ## How to run python code

# %% [markdown]
# ###  Python Interpreter
#
# Python Interpreter from terminal: The most basic way to execute Python code is line by line within the Python interpreter. This can be started by typing python at the command prompt: <br><br>
#
#    - type `python` to start the interpreter  <br><br>
#    - type `1+2`    <br><br>
#    - type print("Hello World")  <br><br>
#
#
# ###  IPython Interpreter
#
# The IPython interpreter: An exhnace python interpreter called IPython (for Interactive Python) is bundled with the Anaconda distribution, and includes a host of convenient enhancements to the basic Python interpreter. It can be started by typing ipython at the command prompt: <br><br>
#
#       - type `IPython` to start the Ipython interpreter   <br><br>
#       - type `1+2`   <br><br>
#       - type print("Hello World")  <br><br>
#
#
# ###  Self-contained Python scripts
#
# Self-contained Python scripts : Running Python snippets line by line is useful in some cases, but for more complicated programs it is more convenient to save code to file, and execute it all at once. By convention, Python scripts are saved in files with a .py extension <br><br>
#
#    - To run a Python script, navigate where the python file is located  <br><br>
#    - run the command `python filename.py`  <br><br>
#    - Alternatively, right click on the `python filename.py`  and select run in the terminal or use the run button on Vscode
#
#
# ###  Jupyter Notebook
#
#
# Jupyter Notebook: Jupyter Notebook is an interactive computing environment that allows you to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.  <br><br>
#
#
# #### Key Features of Jupyter Notebooks:
#
# - Interactive Coding: Run code cells interactively.
#
# - Rich Text Support: Integrate markdown and LaTeX for formatting and documentation.
#
# - Data Visualization: Support for visual output like graphs and charts.
#
# - Multiple Languages: Support for various programming languages (Python, R, Julia, etc.), with Python being the most popular.

# %% [markdown]
# ###  Create a New Notebook
#
# - Create a New Notebook
# - Rename your notebook by clicking on "Untitled" at the top and entering a new name
#
# ### Understanding cells
#
# - Code Cells: For writing and running code
# - Markdown Cells: For writing formatted text using Markdown.
#
#
#   ### Running Code Cells
#
#   - Type Python code in a code cell and press Shift + Enter to execute.
#   -  The output will appear directly below the cell.
#
#
# ###  Adding Text with Markdown Cells
#
# - Markdown cells allow you to write and format text using Markdown.
# - Markdown cells can be used to add headings, lists, links, images, and more.
# - Markdown  cells can be used to add paragraphs and bullet points. For example you can add paragraphs and bullet points as shown below:
#
#   - To add a new cell, click on the "+" button in the toolbar and select the cell type.
#   - To change the cell type, click on the cell and select the desired type from the dropdown menu in the toolbar.
#   - To edit a cell, double-click on it.
#   - To render a cell, press Shift + Enter.
#   - To delete a cell, click on the delete icon in the toolbar.
#   - To move a cell, click on the cell and use the up and down arrows in the toolbar.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.plot(x, y)
plt.title("Sample Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# Managing Python Enviroment : Pipenv vs virtualenv vs conda environment

# %% [markdown]
# ## Installing Python Packages
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pip
#
# > PIP is a package management system used to install and manage software packages written in Python. It stands for “preferred installer program” or “Pip Installs Packages.”
# >
# - If you installed Python from source, with an installer from python.org, or via Homebrew you should already have pip. <br><br>
# - pip is the package installer for Python <br><br>
# - It’s a tool to install python packages from the Python Package Index(PyPi). PyPi is the central repository for all the open-source and third-party python packages <br><br>
# - It is the most popular way to install, upgrade, and remove third-party libraries.  <br><br>
# - pip doesn’t usually come with standard python installation and we have to install pip separately. But, from python 3.4 version, pip is a part of the standard installation <br><br>

# %% [markdown]
# ### Installation using pip

# %% [markdown]
#  - On command Line: use `Pip install <packagename>` ... <br></br>
#  - Jupyter or Ipython : If you’re using an enhanced shell like IPython or the Jupyter notebook, you can run system commands like those in this tutorial by prefacing them with a ! character  `!Pip install <packagename>`

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (6.15.1)
# Requirement already satisfied: appnope in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (8.13.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (8.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: backcall in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: typing-extensions in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (5.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/shmuhammad/.local/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel) (2.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/shmuhammad/mambaforge/envs/datascience/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)

# %% [markdown]
# ## Conda
#
# To install conda packages, in the terminal or an Anaconda Prompt, run:

# %% [markdown]
# - conda install [packagename] <br></br>
# - conda update is used to update to the latest compatible version. conda install can be used to install any version

# %% [markdown]
# > Conda uses the same rules for other packages. conda update always installs the highest version with the same major version number, whereas conda install always installs the highest version

# %% [markdown]
# - If Python 2.7.0 is currently installed, and the latest version of Python 2 is 2.7.5, then conda update python installs Python 2.7.5. It does not install Python 3. <br></br>
# - If Python 3.7.0 is currently installed, and the latest version of Python is 3.9.0, then conda install python=3 installs Python 3.9.0. <br></br>

# %% [markdown]
# ##  Virtual Environments
#
# ![image.png](attachment:image.png)
#
# - A virtual environment is a tool that helps to keep dependencies required by different projects separate by creating isolated spaces for them that contain per-project dependencies for them rather than being installed globally. <br></br>
#
#
# - Users can create virtual environments using one of several tools such as Pipenv or Poetry, or a conda virtual environment.
#
# - Pipenv and Poetry are based around Python's built-in venv library, whereas conda has its own notion of virtual environments that is lower-level (Python itself is a dependency provided in conda environments).

# %% [markdown]
# ### How to create Virtual enviroment?
#
# We can create a virtual environment using conda or virtualenv <br></br>
#
#
# #### Creating a virtual environment using Conda
#
# 1. `conda create --name <enviroment name>`  - Create a new environment using the given environment name and
# 2. `conda create --name <enviroment name> packagename1 packagename2`   - Create a new environment using the given environment name and python version
# 3. `conda activate <enviroment name>` - Activate the environment
# 4. `conda install <package name>` - Install the package in the environment
# 5. `conda deactivate` - Deactivate the environment
#
#
# > Note: If you’re using Conda 4.10 or later, use --name instead of -n to create a new environment.
#
# > Remember to replace <environment_name> and package names as per your needs.
#
#
#
# #### Creating a virtual environment using Virtualenv
#
# 1. `python -m venv <enviroment name>`  - Create a new environment using the given environment name and
# 2. `source <enviroment name>/bin/activate` - Activate the environment
# 3. `pip install <package name>` - Install the package in the environment
# 4. `deactivate` - Deactivate the environment

# %% [markdown]
# Conda Cheetsheet: [here](https://docs.conda.io/projects/conda/en/latest/user-guide/cheatsheet.html)
# More info: [Conda Enviroment Management](https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-with-commands)

# %% [markdown]
# ## Resources
#
#
# 1. [Create and manage Python environments in Visual Studio](https://learn.microsoft.com/en-us/visualstudio/python/managing-python-environments-in-visual-studio?view=vs-2022)
# 2. [Python Virtual Environments: A Primer](https://realpython.com/python-virtual-environments-a-primer/)
